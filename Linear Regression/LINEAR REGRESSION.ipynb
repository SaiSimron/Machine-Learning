# %%
import numpy as nm  
import matplotlib.pyplot as mtp  
from sklearn import linear_model 
import pandas as pd  
dataset = pd.read_excel('Medals.xlsx') 
x = dataset.iloc[:, [0, 6]].values  
y = dataset.iloc[:, [0, 6]].values  
from sklearn.model_selection import train_test_split  
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 0) 

lin_reg=linear_model.LinearRegression()
lin_reg.fit(x_train,y_train)
lin_reg_pred=lin_reg.predict(x_test)

mtp.scatter(x_test, y_test, color = 'red')
mtp.plot(x_test, lin_reg_pred, color = 'blue')
mtp.title('Rank vs Gold')
mtp.xlabel('Rank')
mtp.ylabel('Gold')
mtp.show()

# %%
import numpy as nm  
import matplotlib.pyplot as mtp  
import pandas as pd  
from sklearn import linear_model 
from sklearn.model_selection import train_test_split 
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split 

dataset = pd.read_excel('Medals.xlsx') 
x = dataset.iloc[:, [0, 6]].values  
y = dataset.iloc[:, [0, 6]].values  
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size= 1/3, random_state=0)
from sklearn.linear_model import LinearRegression 

lin_reg=linear_model.LinearRegression()
lin_reg.fit(x_train,y_train)
y_pred=lin_reg.predict(x_test)
x_pred=lin_reg.predict(x_train)

#coef_ and intercept_ are coefficients and intercepts resp. for our m
print("Coefficients:\n",lin_reg.coef_)
print("Intercept:\n",lin_reg.intercept_)
# The mean squared error
print("Mean squared error: %.2f"
 % mean_squared_error(y_test, y_pred))
# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, y_pred))

mtp.scatter(x_train, y_train, color="red")   
mtp.plot(x_train, x_pred, color="black")    
mtp.title("Rank vs Gold(Training Dataset)")  
mtp.xlabel("Rank")  
mtp.ylabel("Gold")  
mtp.show()

mtp.scatter(x_test, y_test, color="blue")   
mtp.plot(x_train, x_pred, color="red")    
mtp.title("Rank vs Gold (Test Dataset)")  
mtp.xlabel("Rank")  
mtp.ylabel("Gold")  
mtp.show()
# Out:
# Coefficients:
#  [[ 1.0000000e+00 -1.3732264e-16]
#  [ 1.3732264e-16  1.0000000e+00]]
# Intercept:
#  [ 3.55271368e-14 -7.10542736e-15]
# Mean squared error: 0.00
# Variance score: 1.00

# %%
#import libraries
import matplotlib.pyplot as plt                                 #for plotting graph of x,y
import numpy as np                                             #for using data as array
from sklearn import linear_model                              #for model we want to predict by
import pandas as pd                                          #for loading csv file data to numpy array
from sklearn.metrics import mean_squared_error, r2_score     #for mean error and variance calculation
from sklearn.model_selection import train_test_split        #splitting training and testing sets

#load dataset
dataset = pd.read_excel('Medals.xlsx') 

#splitting to independent(x) and dependent(y) variables
x=dataset.iloc[:,2].values
y=dataset.iloc[:,5].values

#train and test data split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 1/3, random_state = 0)

#reshaping array to convert from 1D to 2D array
x_test=x_test.reshape(-1,1)
x_train=x_train.reshape(-1,1)

#"lin_reg" is our model calling model "LinearRegression()"
lin_reg=linear_model.LinearRegression()

#fitting our data in linear regression model
lin_reg.fit(x_train,y_train)

#making predictions
lin_reg_pred=lin_reg.predict(x_test)
lin_reg_pred2=lin_reg.predict(x_train)

#coef_ and intercept_ are coefficients and intercepts resp. for our model
print("Coefficients:\n",lin_reg.coef_)
print("Intercept:\n",lin_reg.intercept_)

# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(y_test, lin_reg_pred))

# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, lin_reg_pred))

mtp.scatter(x_train, y_train, color="red")   
mtp.plot(x_train, lin_reg_pred2, color="black")    
mtp.title("Gold vs Total Medals (Training Dataset)")  
mtp.xlabel("Gold")  
mtp.ylabel("Total Medals")  
mtp.show()

mtp.scatter(x_test, y_test, color="blue")   
mtp.plot(x_train, lin_reg_pred2, color="red")    
mtp.title("Gold vs Total Medals (Test Dataset)")  
mtp.xlabel("Gold")  
mtp.ylabel("Total Medals")  
mtp.show()
# Out:
# Coefficients:
#  [2.71292111]
# Intercept:
#  1.6551839819196363
# Mean squared error: 28.31
# Variance score: 0.84

# %%
#import libraries
import matplotlib.pyplot as plt                                 #for plotting graph of x,y
import numpy as np                                             #for using data as array
from sklearn import linear_model                              #for model we want to predict by
import pandas as pd                                          #for loading csv file data to numpy array
from sklearn.metrics import mean_squared_error, r2_score     #for mean error and variance calculation
from sklearn.model_selection import train_test_split        #splitting training and testing sets

#load dataset
dataset = pd.read_excel('Medals.xlsx') 

#splitting to independent(x) and dependent(y) variables
x=dataset.iloc[:,5].values
y=dataset.iloc[:,6].values

#train and test data split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 1/3, random_state = 0)

#reshaping array to convert from 1D to 2D array
x_test=x_test.reshape(-1,1)
x_train=x_train.reshape(-1,1)

#"lin_reg" is our model calling model "LinearRegression()"
lin_reg=linear_model.LinearRegression()

#fitting our data in linear regression model
lin_reg.fit(x_train,y_train)

#making predictions
lin_reg_pred=lin_reg.predict(x_test)
lin_reg_pred2=lin_reg.predict(x_train)

#coef_ and intercept_ are coefficients and intercepts resp. for our model
print("Coefficients:\n",lin_reg.coef_)
print("Intercept:\n",lin_reg.intercept_)

# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(y_test, lin_reg_pred))

# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, lin_reg_pred))

#Plotting the graph for test dataset
# plt.scatter(x_test, y_test, color = 'red')
# plt.plot(x_test, lin_reg_pred, color = 'blue')
# plt.title('Temperature vs Humidity(Test set)')
# plt.xlabel('Temperature')
# plt.ylabel('Relative Humidity')
# plt.show()


mtp.scatter(x_train, y_train, color="red")   
mtp.plot(x_train, lin_reg_pred2, color="black")    
mtp.title("Total vs Rank by Total (Training Dataset)")  
mtp.xlabel("Total")  
mtp.ylabel("Rank by Total")  
mtp.show()

mtp.scatter(x_test, y_test, color="blue")   
mtp.plot(x_train, lin_reg_pred2, color="red")    
mtp.title("Total vs Rank by Total (Test Dataset)")  
mtp.xlabel("Total")  
mtp.ylabel("Rank by Total")  
mtp.show()
# Out:
# Coefficients:
#  [-0.76950218]
# Intercept:
#  52.50833352557154
# Mean squared error: 294.09
# Variance score: 0.49

# %%
#import libraries
import matplotlib.pyplot as plt                                 #for plotting graph of x,y
import numpy as np                                             #for using data as array
from sklearn import linear_model                              #for model we want to predict by
import pandas as pd                                          #for loading csv file data to numpy array
from sklearn.metrics import mean_squared_error, r2_score     #for mean error and variance calculation
from sklearn.model_selection import train_test_split        #splitting training and testing sets

#load dataset
dataset = pd.read_csv('weather.csv') 

#splitting to independent(x) and dependent(y) variables
x=dataset.iloc[:,2].values
y=dataset.iloc[:,3].values

#train and test data split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 1/3, random_state = 0)

#reshaping array to convert from 1D to 2D array
x_test=x_test.reshape(-1,1)
x_train=x_train.reshape(-1,1)

#"lin_reg" is our model calling model "LinearRegression()"
lin_reg=linear_model.LinearRegression()

#fitting our data in linear regression model
lin_reg.fit(x_train,y_train)

#making predictions
lin_reg_pred=lin_reg.predict(x_test)

#coef_ and intercept_ are coefficients and intercepts resp. for our model
print("Coefficients:\n",lin_reg.coef_)
print("Intercept:\n",lin_reg.intercept_)

# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(y_test, lin_reg_pred))

# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, lin_reg_pred))

#Plotting the graph for test dataset
plt.scatter(x_test, y_test, color = 'red')
plt.plot(x_test, lin_reg_pred, color = 'blue')
plt.title('Temperature vs Humidity(Test set)')
plt.xlabel('Temperature')
plt.ylabel('Relative Humidity')
plt.show()
# Out:
# Coefficients:
#  [-4.02872657]
# Intercept:
#  194.5221290669885
# Mean squared error: 4.62
# Variance score: 0.87

# %%
#import libraries
import matplotlib.pyplot as mtp                                 #for plotting graph of x,y
import numpy as np                                             #for using data as array
from sklearn import linear_model                              #for model we want to predict by
import pandas as pd                                          #for loading csv file data to numpy array
from sklearn.metrics import mean_squared_error, r2_score     #for mean error and variance calculation
from sklearn.model_selection import train_test_split        #splitting training and testing sets

#load dataset
dataset = pd.read_csv('weather.csv') 

#splitting to independent(x) and dependent(y) variables
x=dataset.iloc[:,2].values
y=dataset.iloc[:,3].values

#train and test data split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 1/3, random_state = 0)

#reshaping array to convert from 1D to 2D array
x_test=x_test.reshape(-1,1)
x_train=x_train.reshape(-1,1)

#"lin_reg" is our model calling model "LinearRegression()"
lin_reg=linear_model.LinearRegression()

#fitting our data in linear regression model
lin_reg.fit(x_train,y_train)

#making predictions
lin_reg_pred=lin_reg.predict(x_test)
lin_reg_pred2=lin_reg.predict(x_train)

#coef_ and intercept_ are coefficients and intercepts resp. for our model
print("Coefficients:\n",lin_reg.coef_)
print("Intercept:\n",lin_reg.intercept_)

# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(y_test, lin_reg_pred))

# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, lin_reg_pred))

mtp.scatter(x_train, y_train, color="red")   
mtp.plot(x_train, lin_reg_pred2, color="black")    
mtp.title("Temperature vs Relative Humidity (Training Dataset)")  
mtp.xlabel("Temperature")  
mtp.ylabel("Relative Humidity")  
mtp.show()

mtp.scatter(x_test, y_test, color="blue")   
mtp.plot(x_train, lin_reg_pred2, color="red")    
mtp.title("Temperature vs Relative Humidity (Test Dataset)")  
mtp.xlabel("Temperature")  
mtp.ylabel("Relative Humidity")  
mtp.show()
# Out:
# Coefficients:
#  [-4.02872657]
# Intercept:
#  194.5221290669885
# Mean squared error: 4.62
# Variance score: 0.87

# %%
#import libraries
import matplotlib.pyplot as mtp                                 #for plotting graph of x,y
import numpy as np                                             #for using data as array
from sklearn import linear_model                              #for model we want to predict by
import pandas as pd                                          #for loading csv file data to numpy array
from sklearn.metrics import mean_squared_error, r2_score     #for mean error and variance calculation
from sklearn.model_selection import train_test_split        #splitting training and testing sets

#load dataset
dataset = pd.read_csv('weather.csv') 

#splitting to independent(x) and dependent(y) variables
x=dataset.iloc[:,4].values
y=dataset.iloc[:,5].values

#train and test data split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 1/3, random_state = 0)

#reshaping array to convert from 1D to 2D array
x_test=x_test.reshape(-1,1)
x_train=x_train.reshape(-1,1)

#"lin_reg" is our model calling model "LinearRegression()"
lin_reg=linear_model.LinearRegression()

#fitting our data in linear regression model
lin_reg.fit(x_train,y_train)

#making predictions
lin_reg_pred=lin_reg.predict(x_test)
lin_reg_pred2=lin_reg.predict(x_train)

#coef_ and intercept_ are coefficients and intercepts resp. for our model
print("Coefficients:\n",lin_reg.coef_)
print("Intercept:\n",lin_reg.intercept_)

# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(y_test, lin_reg_pred))

# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, lin_reg_pred))

mtp.scatter(x_train, y_train, color="red")   
mtp.plot(x_train, lin_reg_pred2, color="black")    
mtp.title("Wind Speed vs Wind Direction (Training Dataset)")  
mtp.xlabel("Wind Speed")  
mtp.ylabel("Wind Direction")  
mtp.show()

mtp.scatter(x_test, y_test, color="blue")   
mtp.plot(x_train, lin_reg_pred2, color="red")    
mtp.title("Wind Speed Vs Wind Direction (Test Dataset)")  
mtp.xlabel("Wind Speed")  
mtp.ylabel("Wind Direction")  
mtp.show()
# Out:
# Coefficients:
#  [-0.3669672]
# Intercept:
#  265.40891622283925
# Mean squared error: 451.07
# Variance score: -0.01

# %%
#import libraries
import matplotlib.pyplot as mtp                                 #for plotting graph of x,y
import numpy as np                                             #for using data as array
from sklearn import linear_model                              #for model we want to predict by
import pandas as pd                                          #for loading csv file data to numpy array
from sklearn.metrics import mean_squared_error, r2_score     #for mean error and variance calculation
from sklearn.model_selection import train_test_split        #splitting training and testing sets

#load dataset
dataset = pd.read_csv('weather.csv') 

#splitting to independent(x) and dependent(y) variables
x=dataset.iloc[:,1].values
y=dataset.iloc[:,2].values

#train and test data split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 1/3, random_state = 0)

#reshaping array to convert from 1D to 2D array
x_test=x_test.reshape(-1,1)
x_train=x_train.reshape(-1,1)

#"lin_reg" is our model calling model "LinearRegression()"
lin_reg=linear_model.LinearRegression()

#fitting our data in linear regression model
lin_reg.fit(x_train,y_train)

#making predictions
lin_reg_pred=lin_reg.predict(x_test)
lin_reg_pred2=lin_reg.predict(x_train)

#coef_ and intercept_ are coefficients and intercepts resp. for our model
print("Coefficients:\n",lin_reg.coef_)
print("Intercept:\n",lin_reg.intercept_)

# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(y_test, lin_reg_pred))

# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, lin_reg_pred))

mtp.scatter(x_train, y_train, color="red")   
mtp.plot(x_train, lin_reg_pred2, color="black")    
mtp.title("Hour vs Temperauture (Training Dataset)")  
mtp.xlabel("Hour")  
mtp.ylabel("Temperature")  
mtp.show()

mtp.scatter(x_test, y_test, color="blue")   
mtp.plot(x_train, lin_reg_pred2, color="red")    
mtp.title("Hour Vs Temperature (Test Dataset)")  
mtp.xlabel("Hour")  
mtp.ylabel("Temperature")  
mtp.show()
# Out:
# Coefficients:
#  [0.05956286]
# Intercept:
#  29.29377667659411
# Mean squared error: 1.64
# Variance score: 0.14

# %%
#import libraries
import matplotlib.pyplot as mtp                                 #for plotting graph of x,y
import numpy as np                                             #for using data as array
from sklearn import linear_model                              #for model we want to predict by
import pandas as pd                                          #for loading csv file data to numpy array
from sklearn.metrics import mean_squared_error, r2_score     #for mean error and variance calculation
from sklearn.model_selection import train_test_split        #splitting training and testing sets

#load dataset
dataset = pd.read_csv('weather.csv') 

#splitting to independent(x) and dependent(y) variables
x=dataset.iloc[:,1].values
y=dataset.iloc[:,3].values

#train and test data split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 1/3, random_state = 0)

#reshaping array to convert from 1D to 2D array
x_test=x_test.reshape(-1,1)
x_train=x_train.reshape(-1,1)

#"lin_reg" is our model calling model "LinearRegression()"
lin_reg=linear_model.LinearRegression()

#fitting our data in linear regression model
lin_reg.fit(x_train,y_train)

#making predictions
lin_reg_pred=lin_reg.predict(x_test)
lin_reg_pred2=lin_reg.predict(x_train)

#coef_ and intercept_ are coefficients and intercepts resp. for our model
print("Coefficients:\n",lin_reg.coef_)
print("Intercept:\n",lin_reg.intercept_)

# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(y_test, lin_reg_pred))

# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, lin_reg_pred))

mtp.scatter(x_train, y_train, color="red")   
mtp.plot(x_train, lin_reg_pred2, color="black")    
mtp.title("Hour vs Relative Humidity (Training Dataset)")  
mtp.xlabel("Hour")  
mtp.ylabel("Relative Humidity")  
mtp.show()

mtp.scatter(x_test, y_test, color="blue")   
mtp.plot(x_train, lin_reg_pred2, color="red")    
mtp.title("Hour Vs Relative Humidity (Test Dataset)")  
mtp.xlabel("Hour")  
mtp.ylabel("Relative Humidity")  
mtp.show()
# Out:
# Coefficients:
#  [-0.23587732]
# Intercept:
#  76.45926746799816
# Mean squared error: 31.50
# Variance score: 0.14

# %%
#import libraries
import matplotlib.pyplot as mtp                                 #for plotting graph of x,y
import numpy as np                                             #for using data as array
from sklearn import linear_model                              #for model we want to predict by
import pandas as pd                                          #for loading csv file data to numpy array
from sklearn.metrics import mean_squared_error, r2_score     #for mean error and variance calculation
from sklearn.model_selection import train_test_split        #splitting training and testing sets

#load dataset
dataset = pd.read_csv('Fastest Fifties All Seasons Combine.csv') 

#splitting to independent(x) and dependent(y) variables
x=dataset.iloc[:,3].values
y=dataset.iloc[:,2].values

#train and test data split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 1/3, random_state = 0)

#reshaping array to convert from 1D to 2D array
x_test=x_test.reshape(-1,1)
x_train=x_train.reshape(-1,1)

#"lin_reg" is our model calling model "LinearRegression()"
lin_reg=linear_model.LinearRegression()

#fitting our data in linear regression model
lin_reg.fit(x_train,y_train)

#making predictions
lin_reg_pred=lin_reg.predict(x_test)
lin_reg_pred2=lin_reg.predict(x_train)

#coef_ and intercept_ are coefficients and intercepts resp. for our model
print("Coefficients:\n",lin_reg.coef_)
print("Intercept:\n",lin_reg.intercept_)

# The mean squared error
print("Mean squared error: %.2f"
      % mean_squared_error(y_test, lin_reg_pred))

# Explained variance score: 1 is perfect prediction
print('Variance score: %.2f' % r2_score(y_test, lin_reg_pred))

mtp.scatter(x_train, y_train, color="red")   
mtp.plot(x_train, lin_reg_pred2, color="black")    
mtp.title("Ball Faced vs Run (Training Dataset)")  
mtp.xlabel("Ball Faced")  
mtp.ylabel("Run")  
mtp.show()

mtp.scatter(x_test, y_test, color="blue")   
mtp.plot(x_train, lin_reg_pred2, color="red")    
mtp.title("Ball Faced vs Run (Test Dataset)")  
mtp.xlabel("Ball Faced")  
mtp.ylabel("Run")  
mtp.show()
# Out:
# Coefficients:
#  [-0.27416982]
# Intercept:
#  76.23609450998504
# Mean squared error: 274.56
# Variance score: 0.01
